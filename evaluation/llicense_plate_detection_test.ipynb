# %%
# !pip install ultralytics -q
from ultralytics import YOLO

model = YOLO("/kaggle/input/notebooks/toquanghan/license-plate-detection/Ket_Qua_Train/license_plate_detection_yolo26m/weights/best.pt")

print("🚀 Bắt đầu chấm điểm trên tập Test...")

metrics = model.val(
    data="/kaggle/input/datasets/toquanghan/license-plate/dataset_yolo/data.yaml",
    split="test",
    project="/kaggle/working/Ket_Qua_Test",
    name="danh_gia",
    exist_ok=True
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# 🚀 Bắt đầu chấm điểm trên tập Test...
# Ultralytics 8.4.92 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14912MiB)
# YOLO26m summary (fused): 132 layers, 20,350,223 parameters, 0 gradients, 67.8 GFLOPs
# ...
# WARNING ⚠️ val: Slow image access detected (ping: 0.0±0.0 ms, read: 19.3±18.8 MB/s, size: 48.0 KB). Use local storage instead of remote/mounted storage for better performance. See https://docs.ultralytics.com/guides/model-training-tips/
# val: Scanning /kaggle/input/datasets/toquanghan/license-plate/dataset_yolo/labels/test... 832 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 832/832 376.4it/s 2.2s
# ...
